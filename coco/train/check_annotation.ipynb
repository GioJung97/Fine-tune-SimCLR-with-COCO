# %%
import json

with open("./_annotations.coco.json", 'r') as f:
    data = json.load(f)

# %%
print(data.keys())
# Out:
# dict_keys(['info', 'licenses', 'categories', 'images', 'annotations'])

# %%
data["categories"][0]
# Out:
# {'id': 0, 'name': 'firefighting-deveces', 'supercategory': 'none'}

# %%
data["images"][0]
# Out:
# {'id': 0,
#  'license': 1,
#  'file_name': '3-2-1b_PNG.rf.097ded96057ba3ded0c92d916e13e9b3.jpg',
#  'height': 689,
#  'width': 813,
#  'date_captured': '2023-11-28T00:08:04+00:00'}

# %%
data["annotations"][0]
# Out:
# {'id': 0,
#  'image_id': 0,
#  'category_id': 31,
#  'bbox': [371, 300, 49, 34],
#  'area': 1666,
#  'segmentation': [],
#  'iscrowd': 0}
